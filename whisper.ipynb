# %% [markdown]
# Goal of this project is to explore using `langchain` to finish question answering in local environment.

# %% [markdown]
# Testing using local mac environment for `whisper`

# %%
import whisper

model = whisper.load_model("base")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:44<00:00, 3.26MiB/s]

# %%
content = model.transcribe("/Users/patrick/Downloads/The Science of Love, Desire and Attachment.mp3")
# Out:
# /Users/patrick/opt/anaconda3/lib/python3.9/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %% [markdown]
# Now I need to test how to finish a long-form transcription using `langchain`.

# %%
content.keys()
# Out:
# dict_keys(['text', 'segments', 'language'])

# %%
content['text']
# Out:
# " Welcome to the Huberman Lab podcast where we discuss science and science-based tools for everyday life. I'm Andrew Huberman and I'm a professor of neurobiology and ophthalmology at Stanford School of Medicine. Today we are going to talk about the psychology and the biology of desire, love, and attachment. Today happens to be Valentine's Day 2022. However, the themes we are going to discuss pertain to desire, love, and attachment on any given day. And indeed, the mechanisms we are going to discuss almost certainly were at play thousands of years ago, hundreds of years ago, and no doubt will still be at play in our minds and in our bodies and in our psychologies for the decade centuries and thousands of years to come. Indeed, today I want to focus on core mechanisms that lead individuals to seek out other individuals with whom to mate with, with whom to have children with or not, with whom to enter short or long-term relationships with, and perhaps to end those relationships or to se
# ...

# %%
text_file = open("/Users/patrick/CodeLab/podcast_reader_local/Docs/The Science of Love, Desire and Attachment.txt", "w")
n = text_file.write(content['text'])
text_file.close()
